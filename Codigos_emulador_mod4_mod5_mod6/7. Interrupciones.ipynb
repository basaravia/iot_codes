# %% [markdown]
# ## Interrupciones #7
#
# ### *Referencias*
# - Raspberry Pi Cookbook by Simon Monk
# - Kolban's book on raspberry pi by Neil Kolban

# %% [markdown]
# ### Interrupcion
# Una interrupcion es detener un proceso para realizar otro, que puede ser solicitado por el usuario

# %% [markdown]
# ![interrupt.png](attachment:interrupt.png)
#
# Fuente:https://virtualirfan.com/history-of-interrupts

# %% [markdown]
# ## Interrupciones externas RPI
# ### Llamada de funciones
#
#   GPIO.add_event_detect ()
#
#   GPIO.add_event_callback ()

# %% [markdown]
# ## Interrupciones externas RPI
# ### Interrupcion de borde
#
#    Interrupcion de borde ascendente GPIO.add_event_detect (BTN_B,   GPIO.RISING, pin lambda: GPIO.output (LED_B, False))
#
#   Interrupcion de borde descendente GPIO.add_event_detect (BTN_B, GPIO.FALLING, pin lambda: GPIO.output (LED_B, True))
#
#   Interrupcion ascendente y descendente GPIO.add_event_detect(BTN_B, GPIO.BOTH, handle)
#
#   ![interrupt%201.png](attachment:interrupt%201.png)
#
#   Fuente:https://medium.com/@rxseger/interrupt-driven-i-o-on-raspberry-pi-3-with-leds-and-pushbuttons-rising-falling-edge-detection-36c14e640fef

# %% [markdown]
# ## Hilos / Threaded
#
# Los hilos son procesos que se ejecutan paralelamente a otros procesos ya ejecutados.
#
# ![thread.png](attachment:thread.png)

# %% [markdown]
# ## 1. Importar Librerias

# %%
#!/usr/bin/python3
__author__ = "Cristian Moyano"
__copyright__ = "Cristian Moyano, 2020"
__credits__ = ["Alexander Saravia", "Cristian Moyano"]
__license__ = "CC BY-NC-SA 4.0"
__version__ = "1.0.0"
__maintainer__ = "Cristian Moyano"
__email__ = "cristian.moyano@ieee.org"
__status__ = "Development"

import RPi.GPIO as GPIO
import os

# %% [markdown]
# ## 2. Declarar puertos y variables
#
# Creacion de variables
#
# Declarar el modo del GPIO
#
# Declarar puertos de entrada

# %%
contaA = 0
contaB = 0

GPIO.setmode(GPIO.BCM)
GPIO.setup(23,GPIO.IN)
GPIO.setup(24,GPIO.IN)

# %% [markdown]
# ## 3. Creacion de funciones
#
# Creamos funciones para ser llamadas

# %%
def CuentaA(channel):
    global contaA
    contaA += 1
    os.system("clear")
    print "Contador A: ", contaA
    print "Contador B: ", contaB

def CuentaB(channel):
    global contaB
    contaB += 1
    os.system("clear")
    print "Contador A: ", contaA
    print "Contador B: ", contaB

#Interrupciones
GPIO.add_event_detect(23, GPIO.RISING, callback = CuentaA)
GPIO.add_event_detect(24, GPIO.RISING, callback = CuentaB)

# %% [markdown]
# ## 4. Imprimir interrupciones

# %%
print "Contador A: ", contaA
print "Contador B: ", contaB

# %% [markdown]
# ## 5. Condicionales
#
# Creamos las condiciones para definir una accion.

# %%
   while(contaA < 5):
    pass

GPIO.cleanup()

# %% [markdown]
# ## Representacion

# %% [markdown]
# ![example%20interrupt.png](attachment:example%20interrupt.png)

# %% [markdown]
# ## Codigo Completo
#
# Fuente: https://stg-pepper.blogspot.com/2015/09/interrupciones-externas-en-raspberry-pi.html

# %%
#!/usr/bin/python3
__author__ = "Cristian Moyano"
__copyright__ = "Cristian Moyano, 2020"
__credits__ = ["Alexander Saravia", "Cristian Moyano"]
__license__ = "CC BY-NC-SA 4.0"
__version__ = "1.0.0"
__maintainer__ = "Cristian Moyano"
__email__ = "cristian.moyano@ieee.org"
__status__ = "Development"

from EmulatorGUI import GPIO
#import RPi.GPIO as GPIO
import os

contaA = 0
contaB = 0

#Setup
GPIO.setmode(GPIO.BCM)
GPIO.setup(23,GPIO.IN)
GPIO.setup(24,GPIO.IN)

#Callbacks
def CuentaA(channel):
    global contaA
    contaA += 1
    os.system("clear")
    print("Contador A: ", contaA)
    print("Contador B: ", contaB)

def CuentaB(channel):
    global contaB
    contaB += 1
    os.system("clear")
    print("Contador A: ", contaA)
    print("Contador B: ", contaB)

#Interrupciones
GPIO.add_event_detect(23, GPIO.RISING, callback = CuentaA)
GPIO.add_event_detect(24, GPIO.RISING, callback = CuentaB)

print("Contador A: ", contaA)
print("Contador B: ", contaB)

#Bucle principal
while(contaA < 5):
    pass

GPIO.cleanup()

# %%
#!/usr/bin/python3
__author__ = "Cristian Moyano"
__copyright__ = "Cristian Moyano, 2020"
__credits__ = ["Alexander Saravia", "Cristian Moyano"]
__license__ = "CC BY-NC-SA 4.0"
__version__ = "1.0.0"
__maintainer__ = "Cristian Moyano"
__email__ = "cristian.moyano@ieee.org"
__status__ = "Development"

from EmulatorGUI import GPIO
#import RPi.GPIO as GPIO
import time

GPIO.setmode(GPIO.BCM)


def my_callback(channel):
    print("Boton presionado")
    
GPIO.setup(18, GPIO.IN, pull_up_down=GPIO.PUD_UP)
GPIO.add_event_detect(18, GPIO.FALLING, callback=my_callback)

i=0
while True:
    i=i+1
    print(i)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-8f404b135147> in <module>()
#      20
#      21 GPIO.setup(18, GPIO.IN, pull_up_down=GPIO.PUD_UP)
# ---> 22 GPIO.add_event_detect(18, GPIO.FALLING, callback=my_callback)
#      23
#      24 i=0
#
# AttributeError: type object 'GPIO' has no attribute 'add_event_detect'

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License"
# style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.
